# %%
import pandas as pd
import numpy as np

# %%
all_data = pd.read_csv("./data/covid-full.csv")
train = pd.read_csv("./data/train.csv")

# %%
all_data.sort_values(by=['submission_date', 'state']).head(65)
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 16536      01/22/2020    AK          0         NaN         NaN         0
# 6678       01/22/2020    AL          0         NaN         NaN         0
# 10176      01/22/2020    AR          0         NaN         NaN         0
# 4452       01/22/2020    AS          0         NaN         NaN         0
# 636        01/22/2020    AZ          0         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 16537      01/23/2020    AK          0         NaN         NaN         0
# 6679       01/23/2020    AL          0         NaN         NaN         0
# 10177      01/23/2020    AR          0         NaN         NaN         0
# 4453       01/23/2020    AS          0         NaN         NaN         0
# 637        01/23/2020    AZ          0         NaN         NaN         0
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
len(us_state_abbrev)
# Out:
# 56

# %%
new_state = list(np.unique(all_data['state']))

# %%
train.head()
# Out:
#    ID Province_State        Date  Confirmed  Deaths  Recovered   Active  \
# 0   0        Alabama  04-12-2020       3563      93        NaN   3470.0
# 1   1         Alaska  04-12-2020        272       8       66.0    264.0
# 2   2        Arizona  04-12-2020       3542     115        NaN   3427.0
# 3   3       Arkansas  04-12-2020       1280      27      367.0   1253.0
# 4   4     California  04-12-2020      22795     640        NaN  22155.0
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 0      75.988020        21583.0                437.0        2.610160
# 1      45.504049         8038.0                 31.0        2.941176
# 2      48.662422        42109.0                  NaN        3.246753
# 3      49.439423        19722.0                130.0        2.109375
# 4      58.137726       190328.0               5234.0        2.812020
#
#    Testing_Rate  Hospitalization_Rate
# 0    460.300152             12.264945
# 1   1344.711576             11.397059
# ...

# %%
s = np.unique(train['Province_State'])

# %%
train_state = set()

for state in s:
    train_state.add(us_state_abbrev[state])
train_state.union(set(new_state))
# Out:
# {'AK',
#  'AL',
#  'AR',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'FL',
#  'GA',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NC',
#  'ND',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY'}
